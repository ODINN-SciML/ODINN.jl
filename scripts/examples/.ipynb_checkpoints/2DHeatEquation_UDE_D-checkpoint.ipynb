# %% [markdown]
# # Universal Differential Equation for a 2D PDE heat equation

# %%
using Pkg; Pkg.activate("../../."); Pkg.instantiate()
using Plots; gr()
using Statistics
using LinearAlgebra
using Zygote
using PaddedViews
using Flux
using Flux: @epochs
using Tullio
# Out:
#   Activating environment at `~/Dropbox/Glacier UDE/ODINN_toy/Project.toml`

# %% [markdown]
# ### Parameter declaration

# %%
nx, ny = 100, 100 # Size of the grid
Δx, Δy = 1, 1
Δt = 0.01
t₁ = 1

D₀ = 1
tolnl = 1e-4
itMax = 100
damp = 0.85
dτsc   = 1.0/3.0
ϵ     = 1e-4            # small number
cfl  = max(Δx^2,Δy^2)/4.1;

# %%
function loss(T, θ, p)
    
    uD = θ[1]
    
    T = heatflow(T, uD, p)

    l_H = sqrt(Flux.Losses.mse(T, T₁; agg=mean))

    return l_H
end
# Out:
# loss (generic function with 1 method)

# %%
function heatflow(T, D::Real, p, tol=Inf)
   
    Δx, Δy, Δt, t₁ = p
    
    total_iter = 0
    t = 0
    
    while t < t₁
        
        iter = 1
        err = 2 * tolnl
        Hold = copy(T)
        dTdt = zeros(nx, ny)
        err = Inf 
        
        while iter < itMax+1 && tol <= err
            
            Err = copy(T)
                    
            F, dτ = Heat(T, D, p)
            
            @tullio ResT[i,j] := -(T[i,j] - Hold[i,j])/Δt + F[pad(i-1,1,1),pad(j-1,1,1)] 
            
            dTdt_ = copy(dTdt)
            @tullio dTdt[i,j] := dTdt_[i,j]*damp + ResT[i,j]
            
            T_ = copy(T)
            #@tullio T[i,j] := max(0.0, T_[i,j] + dTdt[i,j]*dτ[pad(i-1,1,1),pad(j-1,1,1)]) 
            @tullio T[i,j] := max(0.0, T_[i,j] + dτ * dTdt[i,j])
            
            Zygote.ignore() do
                Err .= Err .- T
                err = maximum(Err)
            end 
            
            iter += 1
            total_iter += 1
            
        end
        
        t += Δt
        
    end
    
    return T
    
end
# Out:
# heatflow (generic function with 2 methods)

# %%
function Heat(T, D, p)
   
    Δx, Δy, Δt, t₁ = p
    
    #dTdx = diff(S, dims=1) / Δx
    #dTdy = diff(S, dims=2) / Δy

    dTdx_edges = diff(T[:,2:end - 1], dims=1) / Δx
    dTdy_edges = diff(T[2:end - 1,:], dims=2) / Δy
    
    Fx = -D * dTdx_edges
    Fy = -D * dTdy_edges    
    F = .-(diff(Fx, dims=1) / Δx .+ diff(Fy, dims=2) / Δy) 

    dτ = dτsc * min( 10.0 , 1.0/(1.0/Δt + 1.0/(cfl/(ϵ + D))))
    
    return F, dτ
 
end
# Out:
# Heat (generic function with 1 method)

# %% [markdown]
# ## Generate reference dataset

# %%
p = (Δx, Δy, Δt, t₁)

T₀ = [ 250 * exp( - ( (i - nx/2)^2 + (j - ny/2)^2 ) / 300 ) for i in 1:nx, j in 1:ny ]

T₁ = copy(T₀)
T₁ = heatflow(T₁, D₀, p, 1e-1)

heatmap(T₀, clim=(0, maximum(T₀)), title="T₀")

# %%
heatmap(T₁, clim=(0, maximum(T₀)), title="T₁")

# %%
sqrt( sum((T₁.-T₀).^2) / (nx * ny) )
# Out:
# 0.16311579618178718

# %% [markdown]
# ## Creating a reference dataset with a fake law
#
# Let's assume that $D$ is a function of time

# %%
fakeD(t) = D₀ * exp(2t)

plot(fakeD, 0, t₁, title="Fake D law")

# %%
function heatflow(T, fD::Function, p, tol=Inf)
   
    Δx, Δy, Δt, t₁ = p
    
    total_iter = 0
    t = 0
    
    while t < t₁
        
        iter = 1
        err = 2 * tolnl
        Hold = copy(T)
        dTdt = zeros(nx, ny)
        err = Inf 
        
        while iter < itMax+1 && tol <= err
            
            Err = copy(T)
                    
            D = fD(t)  # compute the diffusivity at each time
            # if iter == 1
            #     println("current D: ", D)
            # end
            
            F, dτ = Heat(T, D, p)
            
            @tullio ResT[i,j] := -(T[i,j] - Hold[i,j])/Δt + F[pad(i-1,1,1),pad(j-1,1,1)] 
            
            dTdt_ = copy(dTdt)
            @tullio dTdt[i,j] := dTdt_[i,j]*damp + ResT[i,j]
            
            T_ = copy(T)
            #@tullio T[i,j] := max(0.0, T_[i,j] + dTdt[i,j]*dτ[pad(i-1,1,1),pad(j-1,1,1)]) 
            @tullio T[i,j] := max(0.0, T_[i,j] + dτ * dTdt[i,j])
            
            Zygote.ignore() do
                Err .= Err .- T
                err = maximum(Err)
            end 
            
            iter += 1
            total_iter += 1
            
        end
        
        t += Δt
        
    end
    
    return T
    
end
# Out:
# heatflow (generic function with 4 methods)

# %%
p = (Δx, Δy, Δt, t₁)

T₂ = copy(T₀)
T₂ = heatflow(T₂, fakeD, p, 1e-1)

heatmap(T₂, clim=(0, maximum(T₀)))

# %%
sqrt( sum((T₂.-T₀).^2) / (nx * ny) )
# Out:
# 0.4581718364679681

# %% [markdown]
# ## Using a neural network to learn D
#
# Now, let's try to reproduce `fakeD()` with a NN.

# %%
function heatflow(T, fD::Function, p, tol=Inf)
   
    Δx, Δy, Δt, t₁ = p
    
    total_iter = 0
    t = 0
    
    while t < t₁
        
        iter = 1
        err = 2 * tolnl
        Hold = copy(T)
        dTdt = zeros(nx, ny)
        err = Inf 
        
        while iter < itMax+1 && tol <= err
            
            Err = copy(T)
                    
            D = fD(t)  # compute the diffusivity at each time
            # if iter == 1
            #     println("current D: ", D)
            # end
            
            F, dτ = Heat(T, D, p)
            
            @tullio ResT[i,j] := -(T[i,j] - Hold[i,j])/Δt + F[pad(i-1,1,1),pad(j-1,1,1)] 
            
            dTdt_ = copy(dTdt)
            @tullio dTdt[i,j] := dTdt_[i,j]*damp + ResT[i,j]
            
            T_ = copy(T)
            #@tullio T[i,j] := max(0.0, T_[i,j] + dTdt[i,j]*dτ[pad(i-1,1,1),pad(j-1,1,1)]) 
            @tullio T[i,j] := max(0.0, T_[i,j] + dτ * dTdt[i,j])
            
            Zygote.ignore() do
                Err .= Err .- T
                err = maximum(Err)
            end 
            
            iter += 1
            total_iter += 1
            
        end
        
        t += Δt
        
    end
    
    return T
    
end
# Out:
# heatflow (generic function with 4 methods)

# %%
function heatflow_NN(T, uD, p, tol=Inf)
   
    Δx, Δy, Δt, t₁ = p
    
    total_iter = 0
    t = 0
    
    while t < t₁
        
        iter = 1
        err = 2 * tolnl
        Hold = copy(T)
        dTdt = zeros(nx, ny)
        err = Inf 
        
        while iter < itMax+1 && tol <= err
            
            Err = copy(T)
                    
            D = uD([t]')[1]  # compute the diffusivity at each time
            #println(D)
            F, dτ = Heat(T, D, p)
            
            @tullio ResT[i,j] := -(T[i,j] - Hold[i,j])/Δt + F[pad(i-1,1,1),pad(j-1,1,1)] 
            
            dTdt_ = copy(dTdt)
            @tullio dTdt[i,j] := dTdt_[i,j]*damp + ResT[i,j]
            
            T_ = copy(T)
            #@tullio T[i,j] := max(0.0, T_[i,j] + dTdt[i,j]*dτ[pad(i-1,1,1),pad(j-1,1,1)]) 
            @tullio T[i,j] := max(0.0, T_[i,j] + dτ * dTdt[i,j])
            
            Zygote.ignore() do
                Err .= Err .- T
                err = maximum(Err)
            end 
            
            iter += 1
            total_iter += 1
            
        end
        
        t += Δt
        
    end
    
    return T
    
end
# Out:
# heatflow_NN (generic function with 2 methods)

# %%
sqnorm(x) = sum(abs2, x)

function loss_NN(T, UD, p, λ=1)

    T = heatflow_NN(T, UD, p)
    l_cost = sqrt(Flux.Losses.mse(T, T₂; agg=mean))
    #l_reg  = sum(sqnorm, ps)

    return l_cost #+ λ * l_reg
end
# Out:
# loss_NN (generic function with 2 methods)

# %%
# Patch suggested by Michael Abbott needed in order to correctly retrieve gradients
Flux.Optimise.update!(opt, x::AbstractMatrix, Δ::AbstractVector) = Flux.Optimise.update!(opt, x, reshape(Δ, size(x)))

function train(loss, p)
    
    leakyrelu(x, a=0.01) = max(a*x, x)
    relu(x) = max(0, x)
    sigmoid_D(x) = .5 + 10 / ( 1 + exp(-x) ) 

    #UD = Chain(
        #Dense(1,10,initb = Flux.zeros), 
        #BatchNorm(10, leakyrelu),
        #Dense(10,5,initb = Flux.zeros), 
        #BatchNorm(5, leakyrelu),
        #Dense(5,1, relu, initb = Flux.zeros) 
    #)
    UD = Chain(
        Dense(1,10,initb = Flux.glorot_normal), 
        Dense(10, 5, x->σ.(x), initb = Flux.glorot_normal),
        #BatchNorm(5, sigmoid),
        #Dense(5,1, sigmoid_D, initb = Flux.glorot_normal) 
        Dense(5, 1, x->σ.(x), initb = Flux.glorot_normal)
    )
    
    
    opt = ADAM(.5)
    losses = []
    @epochs 50 hybrid_train_NN!(loss, UD, p, opt, losses)
    
    return UD, losses
    
end

function hybrid_train_NN!(loss, UD, p, opt, losses)
    
    T = T₀
    θ = Flux.params(UD)
    loss_uD, back_uD = Zygote.pullback(() -> loss(T, UD, p), θ)
    push!(losses, loss_uD)
    
    # println("Current loss: ", loss_uD)
    #println("Current parameter:", θ)
    ∇_uD = back_uD(one(loss_uD))

    #for p in θ
    #    println("Gradients ∇_uD[p]: ", ∇_uD[p])
    #end
    
    # println("Values of NN: ", UD([0., .5, 1.]'))
    all_times = LinRange(0, t₁, 1000)
    #plot(all_times, UD(all_times')')
    
    Flux.Optimise.update!(opt, θ, ∇_uD)
    
    
end
# Out:
# hybrid_train_NN! (generic function with 1 method)

# %%
UD_trained, losses = train(loss_NN, p)
# Out:
# ┌ Info: Epoch 1
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 2
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 3
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 4
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 5
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 6
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 7
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 8
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 9
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 10
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 11
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 12
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 13
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 14
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 15
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 16
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 17
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 18
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 19
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 20
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 21
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 22
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 23
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 24
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 25
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 26
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 27
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 28
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 29
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 30
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 31
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 32
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 33
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 34
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 35
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 36
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 37
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 38
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 39
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 40
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 41
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 42
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 43
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 44
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 45
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 46
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 47
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 48
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 49
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# ┌ Info: Epoch 50
# └ @ Main /Users/Bolib001/.julia/packages/Flux/0c9kI/src/optimise/train.jl:135
# (Chain(Dense(1, 10), Dense(10, 5, #71), Dense(5, 1, #72)), Any[0.3225721443201795, 0.2960922819037624, 0.2952078803389648, 0.29509392525913997, 0.2950688547917449, 0.29506169702123886, 0.29505924770484315, 0.295058286170107, 0.29505786560592684, 0.29505766446759485  …  0.2950574092449533, 0.29505740920849716, 0.29505740917615736, 0.2950574091474003, 0.29505740912179523, 0.29505740909894057, 0.295057409078514, 0.2950574090602374, 0.2950574090438539, 0.295057409029153])

# %%
plot(losses, yaxis=:log, title="Losses")

# %%
all_times = LinRange(0, t₁, 1000)
plot(all_times, UD_trained(all_times')', title="Simulated D values by the NN", yaxis="Diffusivity (D)", xaxis="Time")

# %%
sqnorm(x) = sum(abs2, x)
sum(sqnorm, Flux.params(UD_trained))
# Out:
# 775.0491f0

# %%
m = Chain(
  Dense(1, 2, relu),
  Dense(2, 1))

sqnorm(x) = sum(abs2, x)

ps = Flux.params(m)   # new line

loss(x, y) = Flux.Losses.logitcrossentropy(m(x), y) + sum(sqnorm, ps)

gradient(()->loss(rand(1), rand(1)), params(m))
# Out:
# Grads(...)
